# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanyadt/AIML/blob/main/AIML2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/fifa (1).csv")
df
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 4              4     167495
# ...          ...        ...
# 9514        9514     208024
# 9515        9515     208510
# 9516        9516     209454
# 9517        9517     209992
# 9518        9518     210477
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4     https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                 ...                ...
# 9514  https://sofifa.com/player/208024/murray-wallac...         M. Wallace
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5           5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6           6         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 7           7     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8           8       7826  https://sofifa.com/player/7826/robin-van-persi...
# 9           9     121944  https://sofifa.com/player/121944/bastian-schwe...
#
#           short_name                            long_name  age         dob  \
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0  sofifa_id  \
# 9509        9509     204935
# 9510        9510     205225
# 9511        9511     205519
# 9512        9512     205939
# 9513        9513     206070
# 9514        9514     208024
# 9515        9515     208510
# 9516        9516     209454
# 9517        9517     209992
# 9518        9518     210477
#
#                                              player_url      short_name  \
# 9509  https://sofifa.com/player/204935/jordan-pickfo...     J. Pickford
# 9510  https://sofifa.com/player/205225/murat-akca/15...         M. Akça
# 9511  https://sofifa.com/player/205519/luigi-falcone...      L. Falcone
# 9512  https://sofifa.com/player/205939/onur-bulut/15...        O. Bulut
# 9513  https://sofifa.com/player/206070/maicon-de-sil...          Maicon
# 9514  https://sofifa.com/player/208024/murray-wallac...      M. Wallace
# 9515  https://sofifa.com/player/208510/pelayo-novo-g...          Pelayo
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'sofifa_id', 'player_url', 'short_name', 'long_name',
#        'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club_name',
#        'league_name', 'league_rank', 'overall', 'potential', 'value_eur',
#        'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
# ...

# %%
df=df.drop(columns=['short_name', 'weak_foot', 'real_face'])

# %%
len(df)
# Out:
# 9519

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9519 entries, 0 to 9518
# Data columns (total 81 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  9519 non-null   int64
#  1   sofifa_id                   9519 non-null   int64
#  2   player_url                  9519 non-null   object
#  3   short_name                  9519 non-null   object
#  4   long_name                   9519 non-null   object
#  5   age                         9519 non-null   int64
#  6   dob                         9519 non-null   object
#  7   height_cm                   9519 non-null   int64
#  8   weight_kg                   9519 non-null   int64
#  9   nationality                 9519 non-null   object
#  10  club_name                   9339 non-null   object
#  11  league_name                 9339 non-null   object
#  12  league_rank                 9339 non-null   float64
# ...

# %%
df.iloc[:10, 5:10]
# Out:
#    age         dob  height_cm  weight_kg  nationality
# 0   27  1987-06-24        169         67    Argentina
# 1   29  1985-02-05        185         80     Portugal
# 2   30  1984-01-23        180         80  Netherlands
# 3   32  1981-10-03        195         95       Sweden
# 4   28  1986-03-27        193         92      Germany
# 5   27  1987-01-24        181         81      Uruguay
# 6   30  1984-05-11        170         65        Spain
# 7   23  1991-01-07        173         74      Belgium
# 8   30  1983-08-06        187         71  Netherlands
# 9   29  1984-08-01        183         79      Germany

# %%
df.loc[[3,10,14,23], ['nationality', 'weight_kg', 'height_cm']]
# Out:
#    nationality  weight_kg  height_cm
# 3       Sweden         95        195
# 10      France         72        170
# 14     Germany         66        170
# 23   Argentina         70        180

# %%
df.height_cm.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# sofifa_id                   int64
# player_url                 object
# short_name                 object
# long_name                  object
#                             ...
# goalkeeping_diving          int64
# goalkeeping_handling        int64
# goalkeeping_kicking         int64
# goalkeeping_positioning     int64
# goalkeeping_reflexes        int64
# Length: 81, dtype: object

# %%
df.select_dtypes(include='int64')
# Out:
#       Unnamed: 0  sofifa_id  age  height_cm  weight_kg  overall  potential  \
# 0              0     158023   27        169         67       93         95
# 1              1      20801   29        185         80       92         92
# 2              2       9014   30        180         80       90         90
# 3              3      41236   32        195         95       90         90
# 4              4     167495   28        193         92       90         90
# ...          ...        ...  ...        ...        ...      ...        ...
# 9514        9514     208024   21        188         73       62         69
# 9515        9515     208510   23        183         81       62         69
# 9516        9516     209454   21        182         72       62         69
# 9517        9517     209992   23        180         75       62         69
# 9518        9518     210477   21        173         65       62         69
#
# ...

# %%
df.select_dtypes(exclude='int64')
# Out:
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4     https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                 ...                ...
# 9514  https://sofifa.com/player/208024/murray-wallac...         M. Wallace
# 9515  https://sofifa.com/player/208510/pelayo-novo-g...             Pelayo
# 9516  https://sofifa.com/player/209454/mateusz-lewan...     M. Lewandowski
# 9517  https://sofifa.com/player/209992/andre-fomitsc...      A. Fomitschow
# 9518  https://sofifa.com/player/210477/patrick-mosch...          P. Möschl
#
# ...

# %%
df[['value_eur', 'wage_eur']].cumsum()
# Out:
#         value_eur   wage_eur
# 0       100500000     550000
# 1       179500000     925000
# 2       234000000    1200000
# 3       286500000    1475000
# 4       350000000    1775000
# ...           ...        ...
# 9514  16286999000  193910000
# 9515  16287349000  193912000
# 9516  16287579000  193914000
# 9517  16287854000  193918000
# 9518  16288129000  193922000
#
# [9519 rows x 2 columns]

# %%
df.sample(n=200)
# Out:
#       Unnamed: 0  sofifa_id  \
# 3409        3409     187818
# 2452        2452     192565
# 6686        6686     176384
# 8159        8159     169780
# 8988        8988     209975
# ...          ...        ...
# 6178        6178     158716
# 465          465     169596
# 6653        6653     209954
# 6451        6451     209636
# 2294        2294     171067
#
#                                              player_url    short_name  \
# 3409  https://sofifa.com/player/187818/ariel-borysiu...   A. Borysiuk
# 2452  https://sofifa.com/player/192565/yunus-malli/1...      Y. Malli
# 6686  https://sofifa.com/player/176384/maciej-gostom...  M. Gostomski
# 8159  https://sofifa.com/player/169780/javier-yacuzz...    J. Yacuzzi
# 8988  https://sofifa.com/player/209975/alex-de-lima/...          Alex
# ...                                                 ...           ...
# 6178  https://sofifa.com/player/158716/david-edwards...    D. Edwards
# ...

# %%
df.skill_moves.unique()
# Out:
# array([4, 5, 1, 3, 2])

# %%
df.skill_moves.nunique()
# Out:
# 5

# %%
nationality=["Argentina", "Portugal", "Sweden", "England"]
df[df.nationality.isin(nationality)]
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 3              3      41236
# 23            23     183898
# 26            26     153079
# ...          ...        ...
# 9487        9487     193473
# 9488        9488     193884
# 9496        9496     200291
# 9507        9507     204304
# 9509        9509     204935
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 23    https://sofifa.com/player/183898/angel-di-mari...        A. Di María
# 26    https://sofifa.com/player/153079/sergio-aguero...          S. Agüero
# ...                                                 ...                ...
# 9487  https://sofifa.com/player/193473/ludvig-ohman/...           L. Öhman
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0     sofifa_id          age    height_cm    weight_kg  \
# count  9519.00000    9519.00000  9519.000000  9519.000000  9519.000000
# mean   4759.00000  179000.19771    26.215359   181.239836    76.030991
# std    2748.04294   42483.08224     4.251948     6.712130     6.935811
# min       0.00000       2.00000    16.000000   157.000000    51.000000
# 25%    2379.50000  167600.50000    23.000000   177.000000    71.000000
# 50%    4759.00000  189808.00000    26.000000   181.000000    76.000000
# 75%    7138.50000  205542.50000    29.000000   186.000000    80.000000
# max    9518.00000  225553.00000    44.000000   203.000000   110.000000
#
#        league_rank      overall    potential     value_eur       wage_eur  \
# count  9339.000000  9519.000000  9519.000000  9.519000e+03    9519.000000
# mean      1.256023    68.513814    71.733901  1.711118e+06   20372.097909
# std       0.518541     4.820544     5.333892  3.529089e+06   28378.757177
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# sofifa_id                  0
# player_url                 0
# short_name                 0
# long_name                  0
#                           ..
# goalkeeping_diving         0
# goalkeeping_handling       0
# goalkeeping_kicking        0
# goalkeeping_positioning    0
# goalkeeping_reflexes       0
# Length: 81, dtype: int64
